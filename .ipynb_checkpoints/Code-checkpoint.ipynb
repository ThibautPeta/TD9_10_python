# %%
#import des bibliothèques
import numpy as np
import pandas as pd #parcequ'on est pas des PD nous
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#import de l'ensemble des données
df_2017 = pd.read_csv('valeursfoncieres-2017.txt', sep="|",low_memory=False)
df_2018 = pd.read_csv('valeursfoncieres-2018.txt', sep="|",low_memory=False)
df_2019 = pd.read_csv('valeursfoncieres-2019.txt', sep="|",low_memory=False)
df_2020 = pd.read_csv('valeursfoncieres-2020.txt', sep="|",low_memory=False)
df_2021 = pd.read_csv('valeursfoncieres-2021.txt', sep="|",low_memory=False)

# %%
#affichage des 5 premiers élément du dataframe 2017
df_2017.head()
# Out:
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# 3             NaN             NaN             NaN               1
# 4             NaN             NaN             NaN               1
#
#   Date mutation Nature mutation  ... Surface Carrez du 5eme lot  \
# 0    02/01/2017           Vente  ...                        NaN
# 1    05/01/2017           Vente  ...                        NaN
# 2    06/01/2017           Vente  ...                        NaN
# 3    06/01/2017           Vente  ...                        NaN
# 4    06/01/2017           Vente  ...                        NaN
#
#    Nombre de lots Code type local   Type local Identifiant local  \
# 0               2             2.0  Appartement               NaN
# 1               0             NaN          NaN               NaN
# 2               0             NaN          NaN               NaN
# 3               0             NaN          NaN               NaN
# 4               0             NaN          NaN               NaN
#
#   Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                37.0                        2.0            NaN
# 1                 NaN                        NaN             AB
# 2                 NaN                        NaN              P
# 3                 NaN                        NaN              P
# 4                 NaN                        NaN              P
#
#   Nature culture speciale  Surface terrain
# 0                     NaN              NaN
# 1                     NaN            788.0
# 2                     NaN             42.0
# 3                     NaN             77.0
# 4                     NaN             94.0
#
# [5 rows x 43 columns]

# %%
#petite fonction qui permet de vérifier si une colonne ne contient aucun élément et dans ce cas cette dernière est supprimé
def ColonneVide(df):
    nunique = df.nunique()
    compteur = 0
    for i in df.columns:
        if nunique[compteur] == 0:
            del df[i]
        compteur += 1
    return df

# %%
#on supprime les colonnes vides
df_2017 = ColonneVide(df_2017)
df_2018 = ColonneVide(df_2018)
df_2019 = ColonneVide(df_2019)
df_2020 = ColonneVide(df_2020)
df_2021 = ColonneVide(df_2021)
